# %% [markdown]
# # Feature Engineering - BigMart Sales Prediction

# %%
import pandas as pd

train = pd.read_csv('train_v9rqX0R.csv')
test = pd.read_csv('test_AbJTz2l.csv')

# Handle missing values
train['Item_Weight'].fillna(train['Item_Weight'].mean(), inplace=True)
test['Item_Weight'].fillna(train['Item_Weight'].mean(), inplace=True)

train['Outlet_Size'].fillna(train['Outlet_Size'].mode()[0], inplace=True)
test['Outlet_Size'].fillna(train['Outlet_Size'].mode()[0], inplace=True)

# Fix inconsistent categories
train['Item_Fat_Content'] = train['Item_Fat_Content'].replace({'LF': 'Low Fat', 'low fat': 'Low Fat', 'reg': 'Regular'})
test['Item_Fat_Content'] = test['Item_Fat_Content'].replace({'LF': 'Low Fat', 'low fat': 'Low Fat', 'reg': 'Regular'})

# Create new feature: Outlet_Age
train['Outlet_Age'] = 2025 - train['Outlet_Establishment_Year']
test['Outlet_Age'] = 2025 - test['Outlet_Establishment_Year']

# Encode categorical variables
train_enc = pd.get_dummies(train.drop('Item_Outlet_Sales', axis=1))
test_enc = pd.get_dummies(test)

# Align columns
train_enc, test_enc = train_enc.align(test_enc, join='left', axis=1, fill_value=0)

train_enc.head()
